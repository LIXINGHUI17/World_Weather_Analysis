# %%
# Import the dependencies.
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np

# Import the Weather API key.
from config import weather_api_key

# Step 4. Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Step 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Step 5. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
# Step 6. Retrieve the following information from the API call.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city and ensure imperial data is requested
    city_url = url + "&q=" + city + '&units=imperial'

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | fort nelson
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | guaymas
# Processing Record 6 of Set 1 | brive-la-gaillarde
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | muravlenko
# Processing Record 10 of Set 1 | portland
# Processing Record 11 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 1 | pangai
# Processing Record 13 of Set 1 | ulladulla
# Processing Record 14 of Set 1 | constitucion
# Processing Record 15 of Set 1 | nishihara
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | kuytun
# Processing Record 18 of Set 1 | laguna
# Processing Record 19 of Set 1 | yamada
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | paamiut
# Processing Record 23 of Set 1 | pecos
# Processing Record 24 of Set 1 | kiunga
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | muyezerskiy
# Processing Record 27 of Set 1 | grafton
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | urucui
# Processing Record 30 of Set 1 | kamenka
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | virginia beach
# Processing Record 37 of Set 1 | saldanha
# Processing Record 38 of Set 1 | pingliang
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | taoudenni
# Processing Record 41 of Set 1 | nyuksenitsa
# Processing Record 42 of Set 1 | pitsunda
# Processing Record 43 of Set 1 | vaitape
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | zhiryatino
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | bonthe
# Processing Record 48 of Set 1 | campeche
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | yulara
# Processing Record 1 of Set 2 | bilibino
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | eldorado
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | raudeberg
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | san quintin
# Processing Record 11 of Set 2 | dukat
# Processing Record 12 of Set 2 | oktyabrskiy
# Processing Record 13 of Set 2 | alice springs
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | sorong
# Processing Record 16 of Set 2 | cap-aux-meules
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | san ramon de la nueva oran
# Processing Record 19 of Set 2 | sandpoint
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | rosignol
# Processing Record 22 of Set 2 | gat
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | sandy bay
# Processing Record 25 of Set 2 | pati
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | safita
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | linhares
# Processing Record 30 of Set 2 | krasnovishersk
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | sadu
# Processing Record 34 of Set 2 | berlevag
# Processing Record 35 of Set 2 | vuktyl
# Processing Record 36 of Set 2 | paro
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 2 | acapulco
# Processing Record 40 of Set 2 | inhambane
# Processing Record 41 of Set 2 | necochea
# Processing Record 42 of Set 2 | marathon
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | jalu
# Processing Record 45 of Set 2 | hirara
# Processing Record 46 of Set 2 | kaitangata
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | newcastleton
# Processing Record 2 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 3 | port elizabeth
# Processing Record 4 of Set 3 | ust-tsilma
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | souillac
# Processing Record 9 of Set 3 | bojnurd
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | zeya
# Processing Record 12 of Set 3 | sharjah
# Processing Record 13 of Set 3 | poronaysk
# Processing Record 14 of Set 3 | etchoropo
# Processing Record 15 of Set 3 | baykit
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | mattru
# Processing Record 18 of Set 3 | touros
# Processing Record 19 of Set 3 | tete
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 3 | dovolnoye
# Processing Record 23 of Set 3 | grand gaube
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | carlisle
# Processing Record 26 of Set 3 | talnakh
# Processing Record 27 of Set 3 | tocopilla
# Processing Record 28 of Set 3 | yar-sale
# Processing Record 29 of Set 3 | preobrazheniye
# Processing Record 30 of Set 3 | garowe
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 3 | kahului
# Processing Record 35 of Set 3 | billings
# Processing Record 36 of Set 3 | barrow
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | leshukonskoye
# Processing Record 39 of Set 3 | port lincoln
# Processing Record 40 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | avera
# Processing Record 43 of Set 3 | mitu
# Processing Record 44 of Set 3 | atambua
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | polyarnyy
# Processing Record 47 of Set 3 | msanga
# Processing Record 48 of Set 3 | fuzhou
# Processing Record 49 of Set 3 | kapaa
# Processing Record 50 of Set 3 | sao miguel
# Processing Record 1 of Set 4 | koungou
# Processing Record 2 of Set 4 | sibolga
# Processing Record 3 of Set 4 | college
# Processing Record 4 of Set 4 | asau
# Processing Record 5 of Set 4 | haines junction
# Processing Record 6 of Set 4 | ponta do sol
# Processing Record 7 of Set 4 | jacmel
# Processing Record 8 of Set 4 | butwal
# Processing Record 9 of Set 4 | misratah
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | encheng
# Processing Record 12 of Set 4 | dunyapur
# Processing Record 13 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 4 | acarau
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | dzilam gonzalez
# Processing Record 17 of Set 4 | zabinka
# City not found. Skipping...
# Processing Record 18 of Set 4 | dessau
# Processing Record 19 of Set 4 | valdivia
# Processing Record 20 of Set 4 | rio gallegos
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | tarakan
# Processing Record 26 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 4 | harper
# Processing Record 29 of Set 4 | aleksandrovka
# Processing Record 30 of Set 4 | dromolaxia
# Processing Record 31 of Set 4 | kemise
# Processing Record 32 of Set 4 | port hardy
# Processing Record 33 of Set 4 | trinidad
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | hamilton
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 4 | ilulissat
# Processing Record 40 of Set 4 | minot
# Processing Record 41 of Set 4 | bolobo
# Processing Record 42 of Set 4 | lagoa
# Processing Record 43 of Set 4 | boa vista
# Processing Record 44 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 4 | verkhoyansk
# Processing Record 46 of Set 4 | moose factory
# Processing Record 47 of Set 4 | leningradskiy
# Processing Record 48 of Set 4 | cam ranh
# Processing Record 49 of Set 4 | letlhakane
# Processing Record 50 of Set 4 | lasa
# Processing Record 1 of Set 5 | manono
# Processing Record 2 of Set 5 | beidao
# Processing Record 3 of Set 5 | havoysund
# Processing Record 4 of Set 5 | bahia blanca
# Processing Record 5 of Set 5 | sao joao da barra
# Processing Record 6 of Set 5 | qaanaaq
# Processing Record 7 of Set 5 | bathsheba
# Processing Record 8 of Set 5 | tura
# Processing Record 9 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 5 | imbituba
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | vanavara
# Processing Record 13 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 5 | esperance
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | yumen
# Processing Record 17 of Set 5 | port-de-bouc
# Processing Record 18 of Set 5 | whitstable
# Processing Record 19 of Set 5 | niquelandia
# Processing Record 20 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | isangel
# Processing Record 23 of Set 5 | turukhansk
# Processing Record 24 of Set 5 | honningsvag
# Processing Record 25 of Set 5 | dingle
# Processing Record 26 of Set 5 | saint-augustin
# Processing Record 27 of Set 5 | maridi
# Processing Record 28 of Set 5 | piotrkow trybunalski
# Processing Record 29 of Set 5 | baruun-urt
# Processing Record 30 of Set 5 | baglung
# Processing Record 31 of Set 5 | urumqi
# Processing Record 32 of Set 5 | ellisras
# Processing Record 33 of Set 5 | baykalovo
# Processing Record 34 of Set 5 | lazaro cardenas
# Processing Record 35 of Set 5 | sendhwa
# Processing Record 36 of Set 5 | dhrangadhra
# Processing Record 37 of Set 5 | port blair
# Processing Record 38 of Set 5 | wanaka
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | vostok
# Processing Record 41 of Set 5 | san vicente
# Processing Record 42 of Set 5 | vao
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | snyder
# Processing Record 45 of Set 5 | jaragua
# Processing Record 46 of Set 5 | sechura
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | hilo
# Processing Record 49 of Set 5 | grand-lahou
# Processing Record 50 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 6 | mangrol
# Processing Record 2 of Set 6 | shingu
# Processing Record 3 of Set 6 | marsa matruh
# Processing Record 4 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 6 | dali
# Processing Record 6 of Set 6 | fulitun
# City not found. Skipping...
# Processing Record 7 of Set 6 | alberton
# Processing Record 8 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 6 | knysna
# Processing Record 10 of Set 6 | bilgoraj
# Processing Record 11 of Set 6 | dunedin
# Processing Record 12 of Set 6 | celestun
# Processing Record 13 of Set 6 | abay
# Processing Record 14 of Set 6 | alegrete
# Processing Record 15 of Set 6 | butaritari
# Processing Record 16 of Set 6 | jaguarao
# Processing Record 17 of Set 6 | maniitsoq
# Processing Record 18 of Set 6 | port shepstone
# Processing Record 19 of Set 6 | jiangyou
# Processing Record 20 of Set 6 | bereda
# Processing Record 21 of Set 6 | glendive
# Processing Record 22 of Set 6 | dhidhdhoo
# Processing Record 23 of Set 6 | lata
# Processing Record 24 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 6 | kijang
# Processing Record 26 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 27 of Set 6 | georgetown
# Processing Record 28 of Set 6 | minab
# Processing Record 29 of Set 6 | wanning
# Processing Record 30 of Set 6 | kulhudhuffushi
# Processing Record 31 of Set 6 | high level
# Processing Record 32 of Set 6 | chokurdakh
# Processing Record 33 of Set 6 | suriapet
# Processing Record 34 of Set 6 | agadir
# Processing Record 35 of Set 6 | alugan
# Processing Record 36 of Set 6 | saskylakh
# Processing Record 37 of Set 6 | oranjemund
# Processing Record 38 of Set 6 | alyangula
# Processing Record 39 of Set 6 | ananas
# Processing Record 40 of Set 6 | gold coast
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | cayenne
# Processing Record 43 of Set 6 | lorengau
# Processing Record 44 of Set 6 | moron
# Processing Record 45 of Set 6 | zhicheng
# Processing Record 46 of Set 6 | bethel
# Processing Record 47 of Set 6 | takoradi
# Processing Record 48 of Set 6 | avarua
# Processing Record 49 of Set 6 | east london
# Processing Record 50 of Set 6 | arraial do cabo
# Processing Record 1 of Set 7 | fushun
# Processing Record 2 of Set 7 | gorom-gorom
# Processing Record 3 of Set 7 | barabinsk
# Processing Record 4 of Set 7 | cockburn town
# Processing Record 5 of Set 7 | bera
# Processing Record 6 of Set 7 | kholtoson
# Processing Record 7 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 7 | meulaboh
# Processing Record 9 of Set 7 | choctaw
# Processing Record 10 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 7 | zhanaozen
# Processing Record 13 of Set 7 | san andres
# Processing Record 14 of Set 7 | beloha
# Processing Record 15 of Set 7 | lebu
# Processing Record 16 of Set 7 | beckley
# Processing Record 17 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | at-bashi
# Processing Record 19 of Set 7 | stavern
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | keti bandar
# Processing Record 22 of Set 7 | brandon
# Processing Record 23 of Set 7 | iralaya
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | te anau
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | brzeg
# Processing Record 28 of Set 7 | winnemucca
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | tongren
# Processing Record 31 of Set 7 | kjopsvik
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | khor
# Processing Record 34 of Set 7 | walvis bay
# Processing Record 35 of Set 7 | yining
# Processing Record 36 of Set 7 | victoria
# Processing Record 37 of Set 7 | charlottesville
# Processing Record 38 of Set 7 | poso
# Processing Record 39 of Set 7 | puerto escondido
# Processing Record 40 of Set 7 | manta
# Processing Record 41 of Set 7 | vryburg
# Processing Record 42 of Set 7 | vallenar
# Processing Record 43 of Set 7 | coquimbo
# Processing Record 44 of Set 7 | riesa
# Processing Record 45 of Set 7 | vanimo
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | manica
# Processing Record 48 of Set 7 | bodden town
# Processing Record 49 of Set 7 | shar
# Processing Record 50 of Set 7 | tessalit
# Processing Record 1 of Set 8 | gomel
# Processing Record 2 of Set 8 | chazuta
# Processing Record 3 of Set 8 | ozernovskiy
# Processing Record 4 of Set 8 | kununurra
# Processing Record 5 of Set 8 | veinticinco de mayo
# Processing Record 6 of Set 8 | athabasca
# Processing Record 7 of Set 8 | lumby
# Processing Record 8 of Set 8 | koutsouras
# Processing Record 9 of Set 8 | xingyi
# Processing Record 10 of Set 8 | sibu
# Processing Record 11 of Set 8 | caranavi
# Processing Record 12 of Set 8 | sept-iles
# Processing Record 13 of Set 8 | keetmanshoop
# Processing Record 14 of Set 8 | adrar
# Processing Record 15 of Set 8 | kidal
# Processing Record 16 of Set 8 | abu samrah
# Processing Record 17 of Set 8 | san juan
# Processing Record 18 of Set 8 | cunha
# Processing Record 19 of Set 8 | cap malheureux
# Processing Record 20 of Set 8 | alta floresta
# Processing Record 21 of Set 8 | sakaiminato
# Processing Record 22 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 23 of Set 8 | erdenet
# Processing Record 24 of Set 8 | tabou
# Processing Record 25 of Set 8 | makakilo city
# Processing Record 26 of Set 8 | ouango
# Processing Record 27 of Set 8 | watsa
# Processing Record 28 of Set 8 | kavaratti
# Processing Record 29 of Set 8 | kruisfontein
# Processing Record 30 of Set 8 | maiduguri
# Processing Record 31 of Set 8 | vilyuysk
# Processing Record 32 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 8 | buala
# Processing Record 34 of Set 8 | tyup
# Processing Record 35 of Set 8 | margate
# Processing Record 36 of Set 8 | maromitsa
# Processing Record 37 of Set 8 | cooma
# Processing Record 38 of Set 8 | calvinia
# Processing Record 39 of Set 8 | muroto
# Processing Record 40 of Set 8 | tanout
# Processing Record 41 of Set 8 | berdigestyakh
# Processing Record 42 of Set 8 | manokwari
# Processing Record 43 of Set 8 | el sauzal
# Processing Record 44 of Set 8 | jumla
# Processing Record 45 of Set 8 | youghal
# Processing Record 46 of Set 8 | narsaq
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | kota kinabalu
# Processing Record 49 of Set 8 | polunochnoye
# Processing Record 50 of Set 8 | camopi
# Processing Record 1 of Set 9 | tres picos
# Processing Record 2 of Set 9 | hokitika
# Processing Record 3 of Set 9 | aquiraz
# Processing Record 4 of Set 9 | severo-kurilsk
# Processing Record 5 of Set 9 | college place
# Processing Record 6 of Set 9 | jatiroto
# Processing Record 7 of Set 9 | kawalu
# Processing Record 8 of Set 9 | bhatkal
# Processing Record 9 of Set 9 | basco
# Processing Record 10 of Set 9 | plouzane
# Processing Record 11 of Set 9 | sitangkai
# Processing Record 12 of Set 9 | swan hill
# Processing Record 13 of Set 9 | lakatoro
# Processing Record 14 of Set 9 | saintes
# Processing Record 15 of Set 9 | santa maria
# Processing Record 16 of Set 9 | inuvik
# Processing Record 17 of Set 9 | anadyr
# Processing Record 18 of Set 9 | nabire
# Processing Record 19 of Set 9 | uvinza
# Processing Record 20 of Set 9 | itarema
# Processing Record 21 of Set 9 | kalmunai
# Processing Record 22 of Set 9 | nyurba
# Processing Record 23 of Set 9 | aswan
# Processing Record 24 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 9 | tynda
# Processing Record 26 of Set 9 | sur
# Processing Record 27 of Set 9 | chicxulub
# Processing Record 28 of Set 9 | tagusao
# Processing Record 29 of Set 9 | byron bay
# Processing Record 30 of Set 9 | jacqueville
# Processing Record 31 of Set 9 | namtsy
# Processing Record 32 of Set 9 | roald
# Processing Record 33 of Set 9 | adet
# Processing Record 34 of Set 9 | half moon bay
# Processing Record 35 of Set 9 | khani
# Processing Record 36 of Set 9 | kushima
# Processing Record 37 of Set 9 | kavieng
# Processing Record 38 of Set 9 | aldan
# Processing Record 39 of Set 9 | bambanglipuro
# Processing Record 40 of Set 9 | smidovich
# Processing Record 41 of Set 9 | bull savanna
# Processing Record 42 of Set 9 | dawei
# Processing Record 43 of Set 9 | moen
# Processing Record 44 of Set 9 | husavik
# Processing Record 45 of Set 9 | luwuk
# Processing Record 46 of Set 9 | kollam
# Processing Record 47 of Set 9 | pokanayevka
# City not found. Skipping...
# Processing Record 48 of Set 9 | salta
# Processing Record 49 of Set 9 | kalianget
# Processing Record 50 of Set 9 | ahipara
# Processing Record 1 of Set 10 | russell
# Processing Record 2 of Set 10 | cukai
# Processing Record 3 of Set 10 | saint-joseph
# Processing Record 4 of Set 10 | maragogi
# Processing Record 5 of Set 10 | marienburg
# Processing Record 6 of Set 10 | san cristobal
# Processing Record 7 of Set 10 | hami
# Processing Record 8 of Set 10 | soe
# Processing Record 9 of Set 10 | los llanos de aridane
# Processing Record 10 of Set 10 | tamboril
# Processing Record 11 of Set 10 | waldoboro
# Processing Record 12 of Set 10 | svarstad
# Processing Record 13 of Set 10 | that phanom
# Processing Record 14 of Set 10 | ixtapa
# Processing Record 15 of Set 10 | hofn
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | novosergiyevka
# Processing Record 18 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 19 of Set 10 | khopoli
# Processing Record 20 of Set 10 | estepa
# Processing Record 21 of Set 10 | shahr-e babak
# Processing Record 22 of Set 10 | vrangel
# Processing Record 23 of Set 10 | pangody
# Processing Record 24 of Set 10 | garoua
# Processing Record 25 of Set 10 | nusaybin
# Processing Record 26 of Set 10 | swidnica
# Processing Record 27 of Set 10 | ostrovnoy
# Processing Record 28 of Set 10 | faanui
# Processing Record 29 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 10 | komsomolskiy
# Processing Record 31 of Set 10 | olinda
# Processing Record 32 of Set 10 | plettenberg bay
# Processing Record 33 of Set 10 | sao jose da coroa grande
# Processing Record 34 of Set 10 | matay
# Processing Record 35 of Set 10 | shache
# Processing Record 36 of Set 10 | auki
# Processing Record 37 of Set 10 | fort walton beach
# Processing Record 38 of Set 10 | tchollire
# Processing Record 39 of Set 10 | ciudad bolivar
# Processing Record 40 of Set 10 | mount isa
# Processing Record 41 of Set 10 | guarapari
# Processing Record 42 of Set 10 | santiago
# Processing Record 43 of Set 10 | merauke
# Processing Record 44 of Set 10 | boyolangu
# Processing Record 45 of Set 10 | odweyne
# Processing Record 46 of Set 10 | lavrentiya
# Processing Record 47 of Set 10 | aklavik
# Processing Record 48 of Set 10 | muros
# Processing Record 49 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 10 | korla
# Processing Record 1 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 11 | alofi
# Processing Record 3 of Set 11 | chandbali
# Processing Record 4 of Set 11 | sabha
# Processing Record 5 of Set 11 | rengo
# Processing Record 6 of Set 11 | qasigiannguit
# Processing Record 7 of Set 11 | ayagoz
# Processing Record 8 of Set 11 | oia
# Processing Record 9 of Set 11 | kyabe
# Processing Record 10 of Set 11 | xinzhou
# Processing Record 11 of Set 11 | nan
# Processing Record 12 of Set 11 | evensk
# Processing Record 13 of Set 11 | bardiyah
# Processing Record 14 of Set 11 | hovd
# Processing Record 15 of Set 11 | pochutla
# Processing Record 16 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 17 of Set 11 | mahibadhoo
# Processing Record 18 of Set 11 | issaquah
# Processing Record 19 of Set 11 | angoram
# Processing Record 20 of Set 11 | amahai
# Processing Record 21 of Set 11 | manggar
# Processing Record 22 of Set 11 | fereydun kenar
# Processing Record 23 of Set 11 | batticaloa
# Processing Record 24 of Set 11 | ferme-neuve
# Processing Record 25 of Set 11 | pacific grove
# Processing Record 26 of Set 11 | saint-leu
# Processing Record 27 of Set 11 | harare
# Processing Record 28 of Set 11 | westport
# Processing Record 29 of Set 11 | salinopolis
# Processing Record 30 of Set 11 | ixmiquilpan
# Processing Record 31 of Set 11 | sri aman
# Processing Record 32 of Set 11 | vestmannaeyjar
# Processing Record 33 of Set 11 | san-pedro
# Processing Record 34 of Set 11 | jasper
# Processing Record 35 of Set 11 | coihaique
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | srandakan
# Processing Record 38 of Set 11 | sulur
# Processing Record 39 of Set 11 | tevaitoa
# Processing Record 40 of Set 11 | raga
# Processing Record 41 of Set 11 | mursalimkino
# Processing Record 42 of Set 11 | revelstoke
# Processing Record 43 of Set 11 | maloyaz
# City not found. Skipping...
# Processing Record 44 of Set 11 | boquim
# Processing Record 45 of Set 11 | kirovskiy
# Processing Record 46 of Set 11 | amnat charoen
# Processing Record 47 of Set 11 | kronshagen
# Processing Record 48 of Set 11 | mastic beach
# Processing Record 49 of Set 11 | cabatuan
# Processing Record 50 of Set 11 | aviles
# Processing Record 1 of Set 12 | fairbanks
# Processing Record 2 of Set 12 | la ronge
# Processing Record 3 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 4 of Set 12 | benghazi
# Processing Record 5 of Set 12 | sinnamary
# Processing Record 6 of Set 12 | toowoomba
# Processing Record 7 of Set 12 | riberalta
# Processing Record 8 of Set 12 | quatre cocos
# Processing Record 9 of Set 12 | businga
# Processing Record 10 of Set 12 | harer
# Processing Record 11 of Set 12 | ono
# Processing Record 12 of Set 12 | catamarca
# Processing Record 13 of Set 12 | hambantota
# Processing Record 14 of Set 12 | mujiayingzi
# Processing Record 15 of Set 12 | chaman
# Processing Record 16 of Set 12 | lundazi
# Processing Record 17 of Set 12 | jinchang
# Processing Record 18 of Set 12 | urucuca
# Processing Record 19 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 12 | peace river
# Processing Record 21 of Set 12 | atengo
# Processing Record 22 of Set 12 | altay
# Processing Record 23 of Set 12 | houma
# Processing Record 24 of Set 12 | labuhan
# Processing Record 25 of Set 12 | cheremukhovo
# Processing Record 26 of Set 12 | san felipe
# Processing Record 27 of Set 12 | zavet
# Processing Record 28 of Set 12 | shenkursk
# Processing Record 29 of Set 12 | suzun
# Processing Record 30 of Set 12 | rosarito
# Processing Record 31 of Set 12 | havre-saint-pierre
# Processing Record 32 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 12 | batie
# Processing Record 34 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 12 | gongzhuling
# Processing Record 36 of Set 12 | bichura
# Processing Record 37 of Set 12 | wad rawah
# Processing Record 38 of Set 12 | bailen
# Processing Record 39 of Set 12 | sovetskiy
# Processing Record 40 of Set 12 | nynashamn
# Processing Record 41 of Set 12 | beringovskiy
# Processing Record 42 of Set 12 | seoul
# Processing Record 43 of Set 12 | ulaangom
# Processing Record 44 of Set 12 | anloga
# Processing Record 45 of Set 12 | manaquiri
# Processing Record 46 of Set 12 | morondava
# Processing Record 47 of Set 12 | wilmington
# Processing Record 48 of Set 12 | inta
# Processing Record 49 of Set 12 | sunndalsora
# Processing Record 50 of Set 12 | ermelo
# Processing Record 1 of Set 13 | flinders
# Processing Record 2 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 13 | tukan
# Processing Record 4 of Set 13 | san jeronimo
# Processing Record 5 of Set 13 | bure
# Processing Record 6 of Set 13 | king city
# Processing Record 7 of Set 13 | conceicao do araguaia
# Processing Record 8 of Set 13 | praia da vitoria
# Processing Record 9 of Set 13 | murdochville
# Processing Record 10 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 13 | ankang
# Processing Record 12 of Set 13 | batemans bay
# Processing Record 13 of Set 13 | kedgwick
# Processing Record 14 of Set 13 | chumikan
# Processing Record 15 of Set 13 | elbistan
# Processing Record 16 of Set 13 | ginir
# Processing Record 17 of Set 13 | ewa beach
# Processing Record 18 of Set 13 | quthing
# Processing Record 19 of Set 13 | rocha
# Processing Record 20 of Set 13 | lalomanu
# City not found. Skipping...
# Processing Record 21 of Set 13 | san policarpo
# Processing Record 22 of Set 13 | aranos
# Processing Record 23 of Set 13 | nelson bay
# Processing Record 24 of Set 13 | rio grande
# Processing Record 25 of Set 13 | porbandar
# Processing Record 26 of Set 13 | gannan
# Processing Record 27 of Set 13 | vardo
# Processing Record 28 of Set 13 | krasnoturinsk
# Processing Record 29 of Set 13 | sola
# Processing Record 30 of Set 13 | luderitz
# Processing Record 31 of Set 13 | bud
# Processing Record 32 of Set 13 | neiafu
# Processing Record 33 of Set 13 | palauig
# Processing Record 34 of Set 13 | massaguet
# Processing Record 35 of Set 13 | havelock
# Processing Record 36 of Set 13 | liverpool
# Processing Record 37 of Set 13 | martapura
# Processing Record 38 of Set 13 | ishinomaki
# Processing Record 39 of Set 13 | yarada
# Processing Record 40 of Set 13 | villarrobledo
# Processing Record 41 of Set 13 | maputo
# Processing Record 42 of Set 13 | arona
# Processing Record 43 of Set 13 | henties bay
# Processing Record 44 of Set 13 | candolim
# Processing Record 45 of Set 13 | winslow
# Processing Record 46 of Set 13 | zabaykalsk
# Processing Record 47 of Set 13 | nouadhibou
# Processing Record 48 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 13 | gondanglegi
# Processing Record 50 of Set 13 | mirnyy
# Processing Record 1 of Set 14 | norman wells
# Processing Record 2 of Set 14 | nurota
# Processing Record 3 of Set 14 | makarska
# Processing Record 4 of Set 14 | pangnirtung
# Processing Record 5 of Set 14 | praia grande
# Processing Record 6 of Set 14 | tieli
# Processing Record 7 of Set 14 | mackay
# Processing Record 8 of Set 14 | morrope
# Processing Record 9 of Set 14 | mabaruma
# Processing Record 10 of Set 14 | isla vista
# Processing Record 11 of Set 14 | shetpe
# Processing Record 12 of Set 14 | ypsonas
# Processing Record 13 of Set 14 | roseburg
# Processing Record 14 of Set 14 | aktau
# Processing Record 15 of Set 14 | gaoual
# Processing Record 16 of Set 14 | korem
# Processing Record 17 of Set 14 | corn island
# Processing Record 18 of Set 14 | santa cruz
# Processing Record 19 of Set 14 | road town
# Processing Record 20 of Set 14 | kingston
# Processing Record 21 of Set 14 | markala
# Processing Record 22 of Set 14 | cambre
# Processing Record 23 of Set 14 | mehamn
# Processing Record 24 of Set 14 | ugoofaaru
# Processing Record 25 of Set 14 | sumkino
# Processing Record 26 of Set 14 | tokmak
# Processing Record 27 of Set 14 | obigarm
# Processing Record 28 of Set 14 | huilong
# Processing Record 29 of Set 14 | malkerns
# Processing Record 30 of Set 14 | hay river
# Processing Record 31 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 32 of Set 14 | opuwo
# Processing Record 33 of Set 14 | belyy yar
# Processing Record 34 of Set 14 | trelew
# Processing Record 35 of Set 14 | nikel
# Processing Record 36 of Set 14 | bubaque
# Processing Record 37 of Set 14 | caruray
# Processing Record 38 of Set 14 | sibiti
# Processing Record 39 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 14 | rabo de peixe
# Processing Record 42 of Set 14 | diffa
# Processing Record 43 of Set 14 | enid
# Processing Record 44 of Set 14 | san
# Processing Record 45 of Set 14 | southbridge
# Processing Record 46 of Set 14 | trofors
# Processing Record 47 of Set 14 | selfoss
# Processing Record 48 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 14 | schmallenberg
# Processing Record 50 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 15 | tyrma
# Processing Record 2 of Set 15 | gambela
# Processing Record 3 of Set 15 | xichang
# Processing Record 4 of Set 15 | maloy
# Processing Record 5 of Set 15 | paramonga
# Processing Record 6 of Set 15 | camacha
# Processing Record 7 of Set 15 | omboue
# Processing Record 8 of Set 15 | yagodnoye
# Processing Record 9 of Set 15 | northam
# Processing Record 10 of Set 15 | bastia
# Processing Record 11 of Set 15 | puerto leguizamo
# Processing Record 12 of Set 15 | poyarkovo
# Processing Record 13 of Set 15 | kursk
# Processing Record 14 of Set 15 | biltine
# Processing Record 15 of Set 15 | kpandae
# Processing Record 16 of Set 15 | egvekinot
# Processing Record 17 of Set 15 | atar
# Processing Record 18 of Set 15 | yarensk
# Processing Record 19 of Set 15 | kristinehamn
# Processing Record 20 of Set 15 | ginda
# Processing Record 21 of Set 15 | miandrivazo
# Processing Record 22 of Set 15 | oktyabrskoye
# Processing Record 23 of Set 15 | paratinga
# Processing Record 24 of Set 15 | santa rosa
# Processing Record 25 of Set 15 | maceio
# Processing Record 26 of Set 15 | bobo dioulasso
# Processing Record 27 of Set 15 | la palma
# Processing Record 28 of Set 15 | christchurch
# Processing Record 29 of Set 15 | mozarlandia
# Processing Record 30 of Set 15 | hammerfest
# Processing Record 31 of Set 15 | copperas cove
# Processing Record 32 of Set 15 | boma
# Processing Record 33 of Set 15 | faya
# Processing Record 34 of Set 15 | wilmington island
# Processing Record 35 of Set 15 | olafsvik
# Processing Record 36 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 15 | bukachacha
# Processing Record 38 of Set 15 | ambovombe
# Processing Record 39 of Set 15 | basseterre
# Processing Record 40 of Set 15 | prince rupert
# Processing Record 41 of Set 15 | xuddur
# Processing Record 42 of Set 15 | charlottetown
# Processing Record 43 of Set 15 | nuuk
# Processing Record 44 of Set 15 | ust-koksa
# Processing Record 45 of Set 15 | kohtla-jarve
# Processing Record 46 of Set 15 | brownsville
# Processing Record 47 of Set 15 | nemuro
# Processing Record 48 of Set 15 | bani walid
# Processing Record 49 of Set 15 | enkhuizen
# Processing Record 50 of Set 15 | sao felix do xingu
# Processing Record 1 of Set 16 | kesinga
# Processing Record 2 of Set 16 | lolodorf
# Processing Record 3 of Set 16 | berezovyy
# Processing Record 4 of Set 16 | mareeba
# Processing Record 5 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 16 | konibodom
# Processing Record 7 of Set 16 | poya
# Processing Record 8 of Set 16 | los andes
# Processing Record 9 of Set 16 | bikaner
# Processing Record 10 of Set 16 | bosaso
# Processing Record 11 of Set 16 | laurinburg
# Processing Record 12 of Set 16 | bouloupari
# Processing Record 13 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 16 | lakes entrance
# Processing Record 15 of Set 16 | padang
# Processing Record 16 of Set 16 | birao
# Processing Record 17 of Set 16 | napasar
# Processing Record 18 of Set 16 | bac lieu
# Processing Record 19 of Set 16 | honiara
# Processing Record 20 of Set 16 | imeni poliny osipenko
# Processing Record 21 of Set 16 | bangassou
# Processing Record 22 of Set 16 | burnie
# Processing Record 23 of Set 16 | kungurtug
# Processing Record 24 of Set 16 | tupik
# Processing Record 25 of Set 16 | moba
# Processing Record 26 of Set 16 | ulaanbaatar
# Processing Record 27 of Set 16 | holme
# Processing Record 28 of Set 16 | pavino
# Processing Record 29 of Set 16 | qandahar
# City not found. Skipping...
# Processing Record 30 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 16 | muncar
# Processing Record 32 of Set 16 | gao
# Processing Record 33 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 16 | jacksonville
# Processing Record 35 of Set 16 | ovsyanka
# Processing Record 36 of Set 16 | tapejara
# Processing Record 37 of Set 16 | xiongyue
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Step 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hermanus      ZA -34.4187   19.2345     63.90        74
# 1               Tiksi      RU  71.6872  128.8694     39.27        90
# 2         Fort Nelson      CA  58.8053 -122.7002     60.39        63
# 3          Bredasdorp      ZA -34.5322   20.0403     65.52        59
# 4             Guaymas      MX  27.9333 -110.9000     78.89        73
# 5  Brive-La-Gaillarde      FR  45.2500    1.5000     78.42        43
# 6      Ribeira Grande      PT  38.5167  -28.7000     64.80        52
# 7          Muravlenko      RU  63.7898   74.5230     54.28        43
# 8            Portland      US  45.5234 -122.6762     71.55        67
# 9              Pangai      TO -19.8000 -174.3500     72.01        96
#
#    Cloudiness  Wind Speed Current Description
# 0          11        4.03          few clouds
# 1         100        6.53     overcast clouds
# 2          40        3.44    scattered clouds
# 3          38        5.97    scattered clouds
# 4           1        0.00           clear sky
# 5          87        6.96     overcast clouds
# 6          40       12.66    scattered clouds
# 7         100       16.17     overcast clouds
# 8          20        1.99          few clouds
# 9         100       15.68     very heavy rain

# %%
# Step 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index = False)
